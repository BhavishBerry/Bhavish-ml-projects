# %%
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Crime Data.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  \
# 0                                  THEFT OF IDENTITY
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2                                  THEFT OF IDENTITY
# ...

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1005062 entries, 0 to 1005061
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1005062 non-null  int64
#  1   Date Rptd       1005062 non-null  str
#  2   DATE OCC        1005062 non-null  str
#  3   TIME OCC        1005062 non-null  int64
#  4   AREA            1005062 non-null  int64
#  5   AREA NAME       1005062 non-null  str
#  6   Rpt Dist No     1005062 non-null  int64
#  7   Part 1-2        1005062 non-null  int64
#  8   Crm Cd          1005062 non-null  int64
#  9   Crm Cd Desc     1005062 non-null  str
#  10  Mocodes         853371 non-null   str
#  11  Vict Age        1005062 non-null  int64
#  12  Vict Sex        860345 non-null   str
#  13  Vict Descent    860333 non-null   str
#  14  Premis Cd       1005046 non-null  float64
#  15  Premis Desc     1004474 non-null  str
#  16  Weapon Used Cd  327246 non-null   float64
# ...

# %%
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.005062e+06  1.005062e+06  1.005062e+06  1.005062e+06  1.005062e+06
# mean   2.202237e+08  1.339916e+03  1.069118e+01  1.115577e+03  1.400321e+00
# std    1.319917e+07  6.510525e+02  6.110389e+00  6.111739e+02  4.899635e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209160e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311104e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.005062e+06  1.005062e+06  1.005046e+06   327246.000000  1.005051e+06
# mean   5.001575e+02  2.891497e+01  3.056110e+02      363.956088  4.999180e+02
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151691
# Vict Age                0
# Vict Sex           144717
# Vict Descent       144729
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677816
# Weapon Desc        677816
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935904
# Crm Cd 3          1002748
# Crm Cd 4          1004998
# LOCATION                0
# Cross Street       850825
# LAT                     0
# LON                     0
# dtype: int64

# %%
no_rows = df.shape[0]
null_value_count = df.isnull().sum().to_list()
columns_df = df.columns.to_list()

for column, count in zip(columns_df, null_value_count):
    print(f'null percentage {column}: {count / no_rows * 100:.2f}%')
# Out:
# null percentage DR_NO: 0.00%
# null percentage Date Rptd: 0.00%
# null percentage DATE OCC: 0.00%
# null percentage TIME OCC: 0.00%
# null percentage AREA: 0.00%
# null percentage AREA NAME: 0.00%
# null percentage Rpt Dist No: 0.00%
# null percentage Part 1-2: 0.00%
# null percentage Crm Cd: 0.00%
# null percentage Crm Cd Desc: 0.00%
# null percentage Mocodes: 15.09%
# null percentage Vict Age: 0.00%
# null percentage Vict Sex: 14.40%
# null percentage Vict Descent: 14.40%
# null percentage Premis Cd: 0.00%
# null percentage Premis Desc: 0.06%
# null percentage Weapon Used Cd: 67.44%
# null percentage Weapon Desc: 67.44%
# null percentage Status: 0.00%
# null percentage Status Desc: 0.00%
# null percentage Crm Cd 1: 0.00%
# null percentage Crm Cd 2: 93.12%
# null percentage Crm Cd 3: 99.77%
# null percentage Crm Cd 4: 99.99%
# null percentage LOCATION: 0.00%
# null percentage Cross Street: 84.65%
# null percentage LAT: 0.00%
# null percentage LON: 0.00%

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  \
# 0                                  THEFT OF IDENTITY
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2                                  THEFT OF IDENTITY
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
crm_columns = ['Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4']
df['no_crm'] = df[crm_columns].notna().sum(axis=1)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  \
# 0                                  THEFT OF IDENTITY
# 1     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2                                  THEFT OF IDENTITY
# ...

# %%
df.drop(columns=['Crm Cd 2','Crm Cd 3','Crm Cd 4'],inplace=True)
