# %%
import numpy as np
from PIL import Image #pil=python img library
import matplotlib.pyplot as plt #use for plotting things matplotlib.pyplot as plt
img = Image.open('man_face.jpg').resize((800, 800)) #img=variable img open nd asign in img, resized to match the quadrant coordinates below
img_arr = np.array(img) #img converted into array

plt.imshow(img_arr)  # show the img

# %%
img_arr[200:310,245:400,0]=0
plt.imshow(img_arr)

# %%
img_arr[200:310,400:555,1]=0
plt.imshow(img_arr)

# %%
img_arr[310:420,245:400,2]=0
plt.imshow(img_arr)

# %%
img_arr[310:420,400:555,(0,1)]=0
plt.imshow(img_arr)
