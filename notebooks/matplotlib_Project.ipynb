# %%
import numpy as np
from PIL import Image #pil=python img library
import matplotlib.pyplot as plt #use for plotting things matplotlib.pyplot as plt
img = Image.open('/shraddha.jpg') #img=variable img open nd asign in img
img_arr = np.array(img) #img converted into array

plt.imshow(img_arr)  # show the img

# %%
img_arr[170:360,425:600,0]=0
plt.imshow(img_arr)

# %%
img_arr[170:360,600:771,1]=0
plt.imshow(img_arr)

# %%
img_arr[360:550,425:600,2]=0
plt.imshow(img_arr)

# %%
img_arr[360:550,600:771,(0,1)]=0
plt.imshow(img_arr)
